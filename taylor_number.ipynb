# %%
import math

temp = 43
a = 2.387e-2
b = 1.764e-2
period = 0.05
mu = 0.3

nu = mu / (900 - 900 * (0.00064 * (temp - 15)))

omega = (2 * math.pi) / period
ta = (omega**2 * a * (a - b)**3) / nu**2

print(f"The taylor number for those inputs is: {int(ta)}")
# Out:
# The taylor number for those inputs is: 791
